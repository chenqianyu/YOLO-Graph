# %%
from ovizioapi import OvizioApiNet
# Out:
# [ INIT ] Initialize Ovizio API...
# [ INFO ] Using OsOne Path: C:\Program Files\Ovizio\OsOne\bin
# [  OK  ] File information successfully extracted!
# [ INFO ] OsOne Version: 5.12.13.24463
# [ INIT ] Setting GPU usage to 'True'
# [ INIT ] Checking Config Files
# [  OK  ] Config Files Are Valid
# [ INIT ] Initialization DONE!

# %%
OvizioApiNet.OvizioApiNet
# Out:
# OvizioApiNet.OvizioApiNet

# %%
functions = [f for f in dir(OvizioApiNet.OvizioApiNet) if f.startswith("get")]

# %%
functions + ["set_UseGPU"]
# Out:
# ['get_Acquisition',
#  'get_ApplicationConfigurationPath',
#  'get_CalibrationFile',
#  'get_ChannelsParametersFile',
#  'get_DefaultCaptureParametersFile',
#  'get_DefaultReconstructionParametersFile',
#  'get_ExperimentsPath',
#  'get_Hardware',
#  'get_MetaDataDisplayFile',
#  'get_MicroscopeDirectory',
#  'get_MicroscopeFile',
#  'get_MockupHelperFile',
#  'get_OriginalObjectivesFile',
#  'get_PumpDirectory',
#  'get_PumpParametersDatabaseDirectory',
#  'get_PumpProfilesFile',
#  'get_UseGPU',
#  'get_UserCaptureParametersFile',
#  'get_UserConfigurationPath',
#  'get_UserReconstructionParametersFile',
#  'set_UseGPU']

# %%
OvizioApiNet.OvizioApiNet.get_Acquisition()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundException                     Traceback (most recent call last)
# c:\git\ovizioapi\notebooks\OvizioApiSettings.ipynb Zelle 5 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/git/ovizioapi/notebooks/OvizioApiSettings.ipynb#X33sZmlsZQ%3D%3D?line=0'>1</a> OvizioApiNet.OvizioApiNet.get_Acquisition()
#
# FileNotFoundException: The microscope file do not exists
#    bei OvizioApiNet.Hardware.Hardware..ctor()
#    bei OvizioApiNet.OvizioApiNet.get_Hardware()
#    bei OvizioApiNet.Acquisition.Acquisition..ctor()
#    bei OvizioApiNet.OvizioApiNet.get_Acquisition()

# %%
OvizioApiNet.OvizioApiNet.get_ApplicationConfigurationPath()
# Out:
# 'C:\\Program Files\\Ovizio\\OsOne\\config'

# %%
OvizioApiNet.OvizioApiNet.get_CalibrationFile()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\Calibration\\CalibrationImage.h5'

# %%
OvizioApiNet.OvizioApiNet.get_ChannelsParametersFile()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\config\\channels.xml'

# %%
OvizioApiNet.OvizioApiNet.get_DefaultCaptureParametersFile()
# Out:
# 'C:\\Program Files\\Ovizio\\OsOne\\config\\DefaultCaptureParameters.xml'

# %%
OvizioApiNet.OvizioApiNet.get_DefaultReconstructionParametersFile()
# Out:
# 'C:\\Program Files\\Ovizio\\OsOne\\config\\DefaultReconstructionParameters.xml'

# %%
OvizioApiNet.OvizioApiNet.get_ExperimentsPath()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\Experiments'

# %%
OvizioApiNet.OvizioApiNet.get_Hardware()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundException                     Traceback (most recent call last)
# c:\git\ovizioapi\notebooks\OvizioApiSettings.ipynb Zelle 11 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/git/ovizioapi/notebooks/OvizioApiSettings.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> OvizioApiNet.OvizioApiNet.get_Hardware()
#
# FileNotFoundException: The microscope file do not exists
#    bei OvizioApiNet.Hardware.Hardware..ctor()
#    bei OvizioApiNet.OvizioApiNet.get_Hardware()

# %%
OvizioApiNet.OvizioApiNet.get_MetaDataDisplayFile()
# Out:
# 'C:\\Program Files\\Ovizio\\OsOne\\config\\metaDataDisplay.xml'

# %%
OvizioApiNet.OvizioApiNet.get_MicroscopeDirectory()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\config'

# %%
OvizioApiNet.OvizioApiNet.get_MicroscopeFile()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\config\\microscope.xml'

# %%
OvizioApiNet.OvizioApiNet.get_MockupHelperFile()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\config\\mockupStatus.txt'

# %%
OvizioApiNet.OvizioApiNet.get_OriginalObjectivesFile()
# Out:
# 'C:\\Program Files\\Ovizio\\OsOne\\config\\objectives.xml'

# %%
OvizioApiNet.OvizioApiNet.get_PumpDirectory()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\config'

# %%
OvizioApiNet.OvizioApiNet.get_PumpParametersDatabaseDirectory()
# Out:
# 'C:\\Program Files\\Ovizio\\OsOne\\config'

# %%
OvizioApiNet.OvizioApiNet.get_PumpProfilesFile()
# Out:
# 'C:\\Program Files\\Ovizio\\OsOne\\config\\pumpprofiles.xml'

# %%
OvizioApiNet.OvizioApiNet.get_UseGPU()
# Out:
# False

# %%
OvizioApiNet.OvizioApiNet.get_UserCaptureParametersFile()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\config\\DefaultCaptureParameters.xml'

# %%
OvizioApiNet.OvizioApiNet.get_UserConfigurationPath()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne'

# %%
OvizioApiNet.OvizioApiNet.get_UserReconstructionParametersFile()
# Out:
# 'C:\\Users\\Strice\\AppData\\Roaming\\OsOne\\config\\DefaultReconstructionParameters.xml'

# %%
OvizioApiNet.OvizioApiNet.set_UseGPU(False)
