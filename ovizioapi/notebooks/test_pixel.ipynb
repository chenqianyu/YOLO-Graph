# %%
from ovizioapi.capture import OvizioCapture
# Out:
# [ INIT ] Initialize Ovizio API...
# [ INFO ] Using OsOne Path: C:\Program Files\Ovizio\OsOne\bin
# [  OK  ] File information successfully extracted!
# [ INFO ] OsOne Version: 5.12.13.24463
# [ INIT ] Setting GPU usage to 'False'
# [ INIT ] Checking Config Files
# [  OK  ] Config Files Are Valid
# [ INIT ] Initialization DONE!

# %%
source_capture = "../data/Capture 16.h5"
cpt = OvizioCapture(source_capture)

# %%
display('Phase: %f' % cpt.get_phase(0)[0,0])
display('Amplitude: %f' % cpt.get_intensity(0)[0,0])
display('Hologram: %f' % cpt.get_hologram(0)[0,0])
# Out:
# 'Phase: 0.334509'
# 'Amplitude: 111.000000'
# 'Hologram: 251.000000'

# %%
from ovizioapi.capture import OvizioCapture

# Create a capture object
cpt = OvizioCapture("C:/Users/siko.myo/Desktop/test1.h5")

# Reconstruct the phase images of this capture
for j in range(len(cpt)):
    phase_image = cpt.get_phase(j)
    # ... store the image some where
