# %%
import os
import re
from ovizioapi.metadata import HDF5Document
from datetime import datetime
import pytz

# %%
path = r"..\data\Capture 16.h5"

# %%
# Check if the file path exists
if not os.path.isfile(path):
    raise FileNotFoundError(f"File {path} does not exist!")
# Create and load the capture object
h = HDF5Document()
err = h.Load(path)
# Check if there was an error loading the capture file
if err != 0:
    raise SystemError(f"Capture could ne be loaded. Error Code: {err}")

# %%
HDF5Document.__dict__
# Out:
# mappingproxy({'__repr__': <slot wrapper '__repr__' of 'HDF5Document' objects>,
#               '__hash__': <slot wrapper '__hash__' of 'HDF5Document' objects>,
#               '__call__': <slot wrapper '__call__' of 'HDF5Document' objects>,
#               '__str__': <slot wrapper '__str__' of 'HDF5Document' objects>,
#               '__lt__': <slot wrapper '__lt__' of 'HDF5Document' objects>,
#               '__le__': <slot wrapper '__le__' of 'HDF5Document' objects>,
#               '__eq__': <slot wrapper '__eq__' of 'HDF5Document' objects>,
#               '__ne__': <slot wrapper '__ne__' of 'HDF5Document' objects>,
#               '__gt__': <slot wrapper '__gt__' of 'HDF5Document' objects>,
#               '__ge__': <slot wrapper '__ge__' of 'HDF5Document' objects>,
#               '__iter__': <slot wrapper '__iter__' of 'HDF5Document' objects>,
#               '__init__': <slot wrapper '__init__' of 'HDF5Document' objects>,
# ...

# %%
h.GetIsPhaseStepperMicroscope()
# Out:
# False

# %%
h.GetImageHeight()
# Out:
# 1536

# %%
h.GetPhysicalPixelWidth()
# Out:
# 3.45

# %%
h.GetMetaDataEditableSettings()

# %%
h.GetImageWidth()
# Out:
# 2048

# %%
h.GetIsDifferentialPhaseMicroscope()
# Out:
# True

# %%
h.GetEndDate().ToString()
# Out:
# '25.02.2021 15:24:52'

# %%
h.GetHasFluorescenceChannel()
# Out:
# False

# %%
h.GetIsD3HM()
# Out:
# True

# %%
h.GetMicroscopeMetaName()
# Out:
# 'ILineFD3HMMicroscope'

# %%
h.GetMetaDataScanningPathConfiguration()

# %%
h.GetMetaData()
# Out:
# '<ovizio version="1.0">\n  <hologramMetaData version="2" className="HologramMetaData">\n    <captureInformation version="4" className="CaptureInformation">\n      <guid>{86921fda-b788-4dfe-86d8-a04afceb4cf3}</guid>\n      <creationDate className="TimeStamp">\n        <time>25/02/2021 15:24:52:477000</time>\n        <standardTime>1614263092</standardTime>\n        <microSecondsAfterStandardTime>477000</microSecondsAfterStandardTime>\n      </creationDate>\n      <startDate className="TimeStamp">\n        <time>25/02/2021 15:24:52:477000</time>\n        <standardTime>1614263092</standardTime>\n        <microSecondsAfterStandardTime>477000</microSecondsAfterStandardTime>\n      </startDate>\n      <endDate className="TimeStamp">\n        <time>25/02/2021 15:24:52:577000</time>\n        <standardTime>1614263092</standardTime>\n        <microSecondsAfterStandardTime>577000</microSecondsAfterStandardTime>\n      </endDate>\n      <name></name>\n      <description></description>\n      <hei
# ...

# %%
h.GetMicroscopeSerialNumber()
# Out:
# 'A3TMIC20180719001'

# %%
h.GetLightSourceWaveLength()
# Out:
# 530.0

# %%
h.GetTimeStepDescription()

# %%
h.GetHasHolographicChannel()
# Out:
# True

# %%
h.GetMetaDataAsDictionary()
# Out:
# <System.Collections.Generic.0, Culture=neutral, PublicKeyToken=b77a5c561934e089]] object at 0x0000022D9DA0DE80>

# %%
h.GetMicroscopeModel()
# Out:
# 'AVIO v2.0'

# %%
h.GetSequenceLength()
# Out:
# 10

# %%
h.GetTemperatureMeasurements()
# Out:
# []

# %%
h.GetIsHolographicMicroscope()
# Out:
# True

# %%
h.GetCreationDate().ToString()
# Out:
# '25.02.2021 15:24:52'

# %%
h.GetBioconnectDisposableParameters()

# %%
h.GetStartDate().ToString()
# Out:
# '25.02.2021 15:24:52'

# %%
h.GetMetaDataRecipientParameters()

# %%
h.GetCaptureName()
# Out:
# 'Capture 16'

# %%
h.GetDepthOfInvestigation()
# Out:
# 450.0

# %%
h.HasCalibrationImage()
# Out:
# True

# %%
h.GetMagnification()
# Out:
# 40.0

# %%
h.GetNominalMagnification()
# Out:
# 40.0
